# %% [markdown]
# ## 了解加工摩拜单车数据集

# %%
import pandas as pd
import numpy as np

# %%
#at work
#docAddress = r"D:\Github\Visualization-with-Tableau\Mobike Data\mobike_shanghai_sample_updated.csv"
#at home
#docAddress = r"D:\GitHub\Visualization with Tableau\Mobike Data\mobike_shanghai_sample_updated.csv"
docAddress = r"D:\GitHub\Visualization with Tableau\Mobike Data\mobike_shanghai_sample_updated_location.csv"
df = pd.read_csv(docAddress)

# %%
df.head()
# Out:
#    orderid  bikeid  userid       start_time            start_location  \
# 0    78387  158357   10080   2016/8/20 6:57            121.348,31.389
# 1   891333   92776    6605  2016/8/29 19:09            121.508,31.279
# 2  1106623  152045    8876  2016/8/13 16:17            121.383,31.254
# 3  1389484  196259   10648  2016/8/23 21:34             121.484,31.32
# 4   188537   78208   11735   2016/8/16 7:32  121.407,31.2919999999999
#
#           end_time            end_location_  \
# 0   2016/8/20 7:04           121.357,31.388
# 1  2016/8/29 19:31  121.488999999999,31.271
# 2  2016/8/13 16:36           121.405,31.248
# 3  2016/8/23 21:43           121.471,31.325
# 4   2016/8/16 7:41  121.417999999999,31.288
#
#                                                track
# 0  121.347,31.392#121.348,31.389#121.349,31.390#1...
# 1  121.489,31.270#121.489,31.271#121.490,31.270#1...
# 2  121.381,31.251#121.382,31.251#121.382,31.252#1...
# 3  121.471,31.325#121.472,31.325#121.473,31.324#1...
# ...

# %%
df.shape
# Out:
# (102361, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102361 entries, 0 to 102360
# Data columns (total 8 columns):
# orderid           102361 non-null int64
# bikeid            102361 non-null int64
# userid            102361 non-null int64
# start_time        102361 non-null object
# start_location    102361 non-null object
# end_time          102361 non-null object
# end_location_     102361 non-null object
# track             102361 non-null object
# dtypes: int64(3), object(5)
# memory usage: 6.2+ MB

# %%
df.describe()
# Out:
#             orderid         bikeid         userid
# count  1.023610e+05  102361.000000  102361.000000
# mean   8.940838e+05  155425.868690    7834.435644
# std    5.219651e+05   98816.625402    4530.387938
# min    6.000000e+00       3.000000       1.000000
# 25%    4.386790e+05   74701.000000    4095.000000
# 50%    8.901510e+05  141990.000000    7617.000000
# 75%    1.343252e+06  228303.000000   11278.000000
# max    1.807864e+06  387351.000000   17753.000000

# %%
#检查重复数据
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# 摩拜单车数据集包含102361条数据，10个变量。无缺失值和重复数据，是个比较干净的数据集。

# %%
df.nunique()
# Out:
# orderid           102361
# bikeid             79062
# userid             16887
# start_time         30833
# start_location     22366
# end_time           31297
# end_location_      22700
# track             100117
# dtype: int64

# %% [markdown]
# - 102361个订单中有100117个不重复轨迹，2244个重复轨迹是哪些？
# - 重复轨迹的起始点是否有足够多的单车供使用？

# %%
df_new = df.copy()

# %%
#新建一列统计轨迹点的个数
df_new['spots'] = df['track'].str.count('#') + 1

# %%
df_new.spots.value_counts()
# Out:
# 11     4289
# 12     4256
# 10     4123
# 13     4008
# 14     3995
# 9      3924
# 15     3864
# 8      3679
# 16     3504
# 17     3260
# 7      3213
# 18     3080
# 6      2961
# 19     2868
# 20     2613
# 5      2560
# 21     2433
# 22     2155
# 4      2083
# 23     2070
# 24     1985
# 2      1877
# 3      1813
# 25     1678
# 26     1661
# 27     1523
# 28     1409
# 29     1363
# 30     1258
# 31     1178
#        ...
# 258       1
# 194       1
# 202       1
# 370       1
# 244       1
# 257       1
# 308       1
# 185       1
# 252       1
# 254       1
# 235       1
# 292       1
# 232       1
# 231       1
# 203       1
# 269       1
# 200       1
# 276       1
# 277       1
# 216       1
# 326       1
# 262       1
# 198       1
# 223       1
# 479       1
# 224       1
# 228       1
# 265       1
# 229       1
# 221       1
# Name: spots, Length: 241, dtype: int64

# %%
df_new.spots.sort_values()
# Out:
# 85347       2
# 95166       2
# 10600       2
# 73562       2
# 95170       2
# 82925       2
# 17568       2
# 23047       2
# 69593       2
# 60987       2
# 6572        2
# 1253        2
# 19739       2
# 35204       2
# 98993       2
# 28879       2
# 23516       2
# 17575       2
# 65298       2
# 17585       2
# 41461       2
# 10623       2
# 55158       2
# 17586       2
# 25397       2
# 76309       2
# 26298       2
# 35211       2
# 85530       2
# 98036       2
#          ...
# 41638     223
# 15556     224
# 48234     228
# 16368     229
# 72455     231
# 13235     232
# 27635     234
# 40683     234
# 36102     235
# 60293     239
# 29113     243
# 59010     243
# 75444     244
# 52904     246
# 39081     246
# 58483     252
# 11343     254
# 42231     257
# 81111     258
# 91255     262
# 53375     265
# 100946    269
# 23351     276
# 35232     277
# 8964      292
# 62435     306
# 65610     308
# 81338     326
# 5954      370
# 101327    479
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102361 entries, 0 to 102360
# Data columns (total 11 columns):
# orderid             102361 non-null int64
# bikeid              102361 non-null int64
# userid              102361 non-null int64
# start_time          102361 non-null object
# start_location_x    102361 non-null object
# start_location_y    102361 non-null object
# end_time            102361 non-null object
# end_location_x      102361 non-null object
# end_location_y      102361 non-null object
# track               102361 non-null object
# spots               102361 non-null int64
# dtypes: int64(4), object(7)
# memory usage: 8.6+ MB

# %%
#不知道为什么还是float的形式
#df_new['end_location_x'] = pd.to_string(df_new['end_location_x'])
# df_new['start_location_x'].to_string()
# df_new['start_location_y'].to_string()
# df_new['end_location_x'].to_string()
# df_new['end_location_y'].to_string()
# df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102361 entries, 0 to 102360
# Data columns (total 11 columns):
# orderid             102361 non-null int64
# bikeid              102361 non-null int64
# userid              102361 non-null int64
# start_time          102361 non-null object
# start_location_x    102361 non-null object
# start_location_y    102361 non-null object
# end_time            102361 non-null object
# end_location_x      102361 non-null object
# end_location_y      102361 non-null object
# track               102361 non-null object
# spots               102361 non-null int64
# dtypes: int64(4), object(7)
# memory usage: 8.6+ MB

# %%
# df_new['start_location'] = df_new['start_location_x']
# #df_new['end_location'] = str(df_new['end_location_x']) + ',' + str(df_new['end_location_y'])
# df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102361 entries, 0 to 102360
# Data columns (total 12 columns):
# orderid             102361 non-null int64
# bikeid              102361 non-null int64
# userid              102361 non-null int64
# start_time          102361 non-null object
# start_location_x    102361 non-null object
# start_location_y    102361 non-null object
# end_time            102361 non-null object
# end_location_x      102361 non-null object
# end_location_y      102361 non-null object
# track               102361 non-null object
# spots               102361 non-null int64
# start_location      102361 non-null object
# dtypes: int64(4), object(8)
# memory usage: 9.4+ MB

# %%
# df_new['start_location'].to_string()
# #df_new['start_location'].str.cat(df_new['start_location_y'], sep = ',')
# df_new.head()
# Out:
#    orderid  bikeid  userid        start_time start_location_x  \
# 0    78387  158357   10080  2016-08-20 06:57          121.348
# 1   891333   92776    6605  2016-08-29 19:09          121.508
# 2  1106623  152045    8876  2016-08-13 16:17          121.383
# 3  1389484  196259   10648  2016-08-23 21:34          121.484
# 4   188537   78208   11735  2016-08-16 07:32          121.407
#
#   start_location_y          end_time end_location_x end_location_y  \
# 0           31.389  2016-08-20 07:04        121.357         31.388
# 1           31.279  2016-08-29 19:31        121.489         31.271
# 2           31.254  2016-08-13 16:36        121.405         31.248
# 3            31.32  2016-08-23 21:43        121.471         31.325
# 4           31.292  2016-08-16 07:41        121.418         31.288
#
#                                                track  spots start_location  \
# 0  121.347,31.392#121.348,31.389#121.349,31.390#1...     16        121.348
# ...

# %%
# df_new['whatever'] = df_new['start_location'].str.len()
# df_new.head()
# Out:
#    orderid  bikeid  userid        start_time start_location_x  \
# 0    78387  158357   10080  2016-08-20 06:57          121.348
# 1   891333   92776    6605  2016-08-29 19:09          121.508
# 2  1106623  152045    8876  2016-08-13 16:17          121.383
# 3  1389484  196259   10648  2016-08-23 21:34          121.484
# 4   188537   78208   11735  2016-08-16 07:32          121.407
#
#   start_location_y          end_time end_location_x end_location_y  \
# 0           31.389  2016-08-20 07:04        121.357         31.388
# 1           31.279  2016-08-29 19:31        121.489         31.271
# 2           31.254  2016-08-13 16:36        121.405         31.248
# 3            31.32  2016-08-23 21:43        121.471         31.325
# 4           31.292  2016-08-16 07:41        121.418         31.288
#
#                                                track  spots start_location  \
# 0  121.347,31.392#121.348,31.389#121.349,31.390#1...     16        121.348
# ...

# %%
#df_new['whatever'].str.cat(df_new['track'][0], sep = '||||||||||||||||||||')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'whatever'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-e2af6018c1b9> in <module>()
# ...

# %%
#不成功df_new['dup_track_num'] = df_new['track'].value_counts()

# %%
# df_track = df_new['track']
# df_track = df_track.value_counts()
# df_track.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3123             try:
# -> 3124                 return libindex.get_value_box(s, key)
#    3125             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-a1a0eda9eada> in <module>
#       1 df_track = df_new['track']
# ----> 2 df_track = df_track['track'].value_counts()
#       3 df_track.info()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
# ...

# %%
df_new.sample(20)
# Out:
#         orderid  bikeid  userid        start_time  start_location_x  \
# 100379    48347   11102    7339  2016-08-08 00:46           121.437
# 98504   1318293  309092   13211  2016-08-27 18:16           121.415
# 75303    243731  306600   16867  2016-08-29 09:05           121.426
# 75235    607050   48985    3544  2016-08-31 08:57           121.465
# 21090   1310262  358555    8868  2016-08-28 16:36           121.370
# 31279    513859   81974    9455  2016-08-13 09:49           121.373
# 9381     311355  230467    2965  2016-08-16 07:59           121.491
# 22989   1385205  172364    8271  2016-08-08 20:52           121.504
# 40189    347004  185842    3493  2016-08-18 12:36           121.405
# 17976   1584210  134485    6467  2016-08-19 23:38           121.332
# 42069    811750   62270    5723  2016-08-05 19:13           121.441
# 8640     487608    3258    1056  2016-08-11 10:43           121.529
# 49974   1210401   71325   10220  2016-08-30 14:51           121.480
# ...

# %% [markdown]
# - 路径点只有2个的订单有多少？
# - 路径点少是因为车坏了，还是因为解决的是最后一公里的问题？
# - 路径点的数量跟骑行时间的关系是？

# %%
df_new.head()
# Out:
#    orderid  bikeid  userid        start_time  start_location_x  \
# 0    78387  158357   10080  2016-08-20 06:57           121.348
# 1   891333   92776    6605  2016-08-29 19:09           121.508
# 2  1106623  152045    8876  2016-08-13 16:17           121.383
# 3  1389484  196259   10648  2016-08-23 21:34           121.484
# 4   188537   78208   11735  2016-08-16 07:32           121.407
#
#    start_location_y          end_time  end_location_x  end_location_y  \
# 0            31.389  2016-08-20 07:04         121.357          31.388
# 1            31.279  2016-08-29 19:31         121.489          31.271
# 2            31.254  2016-08-13 16:36         121.405          31.248
# 3            31.320  2016-08-23 21:43         121.471          31.325
# 4            31.292  2016-08-16 07:41         121.418          31.288
#
#                                                track  spots
# 0  121.347,31.392#121.348,31.389#121.349,31.390#1...     16
# ...

# %%
df_new.iloc[4, 9:11]
# Out:
# track    121.407,31.291#121.407,31.292#121.408,31.291#1...
# spots                                                    8
# Name: 4, dtype: object

# %%
df_new.iloc[10600, 9:11]
# Out:
# track    121.337,31.151#121.340,31.150
# spots                                2
# Name: 10600, dtype: object

# %%
path = r"D:\Github\Visualization-with-Tableau\Mobike Data\mobike_shanghai_sample_processed.csv"
df_new.to_csv(path)
